# %% [markdown]
# # 02 – Preprocessing Pipeline
#
# In this notebook, we implement the full preprocessing strategy for the COMPAS dataset used in our case study on risk assessment and bias in automated systems. This pipeline handles missing values, encodes categorical features, scales numerical values, and deduplicates records – all while adhering to the modeling constraints from Dressel & Farid (2018).
#
# We aim to:
# - Keep the raw dataset unchanged (for explorability).
# - Preprocess the cleaned dataset using a scikit-learn `Pipeline`.
# - Save the final pipeline object for later reuse during model training and evaluation.
# - Save a preprocessed csv file after modifications.

# %% [markdown]
# Imports and Configurations

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import os

pd.set_option("display.max_columns", 100)

df = pd.read_csv("../data/cox-violent-parsed.csv")
print(f"Raw dataset shape: {df.shape}")
df.head()
# Out:
# Raw dataset shape: (18316, 52)
#     id              name    first       last compas_screening_date   sex  \
# 0  1.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 1  2.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 2  3.0      michael ryan  michael       ryan            31/12/2014  Male
# 3  4.0       kevon dixon    kevon      dixon            27/01/2013  Male
# 4  5.0          ed philo       ed      philo            14/04/2013  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  18/04/1947   69  Greater than 45             Other              0
# 1  18/04/1947   69  Greater than 45             Other              0
# 2  06/02/1985   31          25 - 45         Caucasian              0
# 3  22/01/1982   34          25 - 45  African-American              0
# 4  14/05/1991   24     Less than 25  African-American              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0             1               0                0             0
# 1             1               0                0             0
# 2             5               0                0             0
# 3             3               0                0             0
# 4             4               0                1             4
#
#    days_b_screening_arrest        c_jail_in       c_jail_out  c_case_number  \
# 0                     -1.0  13/08/2013 6:03  14/08/2013 5:41  13011352CF10A
# 1                     -1.0  13/08/2013 6:03  14/08/2013 5:41  13011352CF10A
# 2                      NaN              NaN              NaN            NaN
# 3                     -1.0  26/01/2013 3:45  05/02/2013 5:36  13001275CF10A
# 4                     -1.0  13/04/2013 4:58  14/04/2013 7:02  13005330CF10A
#
#   c_offense_date c_arrest_date  c_days_from_compas c_charge_degree  \
# 0     13/08/2013           NaN                 1.0            (F3)
# 1     13/08/2013           NaN                 1.0            (F3)
# 2            NaN           NaN                 NaN             NaN
# 3     26/01/2013           NaN                 1.0            (F3)
# 4     13/04/2013           NaN                 1.0            (F3)
#
#                     c_charge_desc  is_recid  r_case_number r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0            NaN             NaN
# 1    Aggravated Assault w/Firearm         0            NaN             NaN
# 2                             NaN        -1            NaN             NaN
# 3  Felony Battery w/Prior Convict         1  13009779CF10A            (F3)
# 4           Possession of Cocaine         1  13011511MM10A            (M1)
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN            NaN                          NaN         NaN
# 2                 NaN            NaN                          NaN         NaN
# 3                 NaN     05/07/2013  Felony Battery (Dom Strang)         NaN
# 4                 0.0     16/06/2013  Driving Under The Influence  16/06/2013
#
#    r_jail_out  violent_recid  is_violent_recid vr_case_number  \
# 0         NaN            NaN                 0            NaN
# 1         NaN            NaN                 0            NaN
# 2         NaN            NaN                 0            NaN
# 3         NaN            NaN                 1  13009779CF10A
# 4  16/06/2013            NaN                 0            NaN
#
#   vr_charge_degree vr_offense_date               vr_charge_desc  \
# 0              NaN             NaN                          NaN
# 1              NaN             NaN                          NaN
# 2              NaN             NaN                          NaN
# 3             (F3)      05/07/2013  Felony Battery (Dom Strang)
# 4              NaN             NaN                          NaN
#
#    type_of_assessment  decile_score.1 score_text screening_date  \
# 0  Risk of Recidivism               1        Low     14/08/2013
# 1  Risk of Recidivism               1        Low     14/08/2013
# 2  Risk of Recidivism               5     Medium     31/12/2014
# 3  Risk of Recidivism               3        Low     27/01/2013
# 4  Risk of Recidivism               4        Low     14/04/2013
#
#   v_type_of_assessment  v_decile_score v_score_text v_screening_date  \
# 0     Risk of Violence               1          Low       14/08/2013
# 1     Risk of Violence               1          Low       14/08/2013
# 2     Risk of Violence               2          Low       31/12/2014
# 3     Risk of Violence               1          Low       27/01/2013
# 4     Risk of Violence               3          Low       14/04/2013
#
#    in_custody out_custody  priors_count.1  start  end  event
# 0  07/07/2014  14/07/2014               0      0  327      0
# 1  07/07/2014  14/07/2014               0    334  961      0
# 2  30/12/2014  03/01/2015               0      3  457      0
# 3  26/01/2013  05/02/2013               0      9  159      1
# 4  16/06/2013  16/06/2013               4      0   63      0

# %% [markdown]
# ## Handle Data Issues (outside pipeline)
#
# - Filter Unknown Targets & Track Initial Size
# - Handle missing values

# %%
# Filter unknown target values (-1 = unknown recidivism)
# Filter unknown targets
df = df[df["is_recid"] != -1].copy()
print(f"Dataset shape after removing unknown 'is_recid': {df.shape}")

# Separate target and features
y = df["is_recid"]
X = df.drop(columns=["is_recid"])
# Out:
# Dataset shape after removing unknown 'is_recid': (17496, 52)

# %% [markdown]
# ## Handle Missing Values outside the pipeline
#
# We apply threshold-based missing value strategies outside the sklearn pipeline:
#
# | Missing Ratio             | Action                    |
# |---------------------------|---------------------------|
# | > 20%                     | Drop feature              |
# | 0–20% (exc. selected f.)  | Impute later via pipeline |
# | < 5% in selected features | Drop rows                 |

# %%
# Define selected modeling features that we handle differently
selected_modeling_features = [
    "age", "sex", "juv_misd_count", "juv_fel_count",
    "priors_count", "c_charge_degree", "c_charge_desc"
]

# Store full column list and initial row count
initial_cols = df.columns.tolist()
initial_row_count = len(df)

# Calculate missing value ratios
missing_ratio = df.isna().mean()

# Drop columns with >20% missing
cols_to_drop = missing_ratio[missing_ratio > 0.20].index.tolist()
df.drop(columns=cols_to_drop, inplace=True)

# Drop rows from selected modeling features with <5% missing
rows_before = len(df)
for col in selected_modeling_features:
    if col in df.columns and df[col].isna().mean() < 0.05:
        df = df[df[col].notna()]
rows_after = len(df)
dropped_rows = rows_before - rows_after

# Summary print
print("=== Missing Value Handling Summary ===")
print(f"- Dropped {len(cols_to_drop)} features with >20% missing values: {cols_to_drop}")
print(f"- Dropped {dropped_rows} rows due to <5% missing values in selected modeling features")
print(f"- Remaining rows: {len(df)}")

# Store result to a new CSV for verification
output_path = "../data/cox-violent-preprocessed.csv"
df.to_csv(output_path, index=False)

# Return updated dataframe shape and column count
df.shape, df.columns.tolist()
# Out:
# === Missing Value Handling Summary ===
# - Dropped 14 features with >20% missing values: ['id', 'c_arrest_date', 'r_case_number', 'r_charge_degree', 'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid', 'vr_case_number', 'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc']
# - Dropped 62 rows due to <5% missing values in selected modeling features
# - Remaining rows: 17434
# ((17434, 38),
#  ['name',
#   'first',
#   'last',
#   'compas_screening_date',
#   'sex',
#   'dob',
#   'age',
#   'age_cat',
#   'race',
#   'juv_fel_count',
#   'decile_score',
#   'juv_misd_count',
#   'juv_other_count',
#   'priors_count',
#   'days_b_screening_arrest',
#   'c_jail_in',
#   'c_jail_out',
#   'c_case_number',
#   'c_offense_date',
#   'c_days_from_compas',
#   'c_charge_degree',
#   'c_charge_desc',
#   'is_recid',
#   'is_violent_recid',
#   'type_of_assessment',
#   'decile_score.1',
#   'score_text',
#   'screening_date',
#   'v_type_of_assessment',
#   'v_decile_score',
#   'v_score_text',
#   'v_screening_date',
#   'in_custody',
#   'out_custody',
#   'priors_count.1',
#   'start',
#   'end',
#   'event'])

# %% [markdown]
# Deduplication Based on Selected Modeling Features

# %%
df_final_cleaned = X.copy()

# Reattach target column for deduplication logic
df_final_cleaned["is_recid"] = y.loc[df_final_cleaned.index]

# Define deduplication subset (selected features + identifiers + target)
dedup_cols = selected_modeling_features + ["name", "dob", "is_recid"]
dedup_subset = df_final_cleaned[dedup_cols]

# Drop duplicates based on deduplication subset
duplicates = dedup_subset.duplicated(keep="first")
n_duplicates = duplicates.sum()
df_final_cleaned = df_final_cleaned[~duplicates].copy()

# Final print
print(f"Deduplication removed {n_duplicates} rows.")
print(f"Final shape after deduplication: {df_final_cleaned.shape}")

# === Step 7: Save Final Preprocessed Dataset ===
df_final_cleaned.to_csv("../data/cox-violent-preprocessed.csv", index=False)
print("Preprocessed dataset saved as: '../data/cox-violent-preprocessed.csv'")
# Out:
# Deduplication removed 7133 rows.
# Final shape after deduplication: (10301, 38)
# Preprocessed dataset saved as: '../data/cox-violent-preprocessed.csv'

# %% [markdown]
# ## Preprocessing Pipeline (Remaining Missing Values, Encoding, Scaling)
#
# All remaining preprocessing steps are included in the sklearn pipeline:
# - Numerical columns: imputed with **mean** and scaled with **StandardScaler**
# - Categorical columns: imputed with **most_frequent** and encoded with **OrdinalEncoder**

# %%
# Identify feature types after dropping
num_features = df.select_dtypes(include=["number"]).drop(columns=["is_recid"]).columns.tolist()
cat_features = df.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

# Pipeline steps
num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])

cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1))
])

# Full preprocessing pipeline
preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_features),
    ("cat", cat_pipeline, cat_features)
])

# Example fit
X = df.drop(columns="is_recid")
y = df["is_recid"]
preprocessor.fit(X)

# (Optional) Save to file
import joblib, os
os.makedirs("../models", exist_ok=True)
joblib.dump(preprocessor, "../models/pipeline_preprocessing.pkl")
print("Preprocessing pipeline saved.")
# Out:
# Preprocessing pipeline saved.

# %% [markdown]
# Numerical Feature Summary

# %%
X[num_features].describe().T
# Out:
#                            count        mean         std    min    25%    50%  \
# age                      17434.0   33.945623   11.594247   18.0   25.0   31.0
# juv_fel_count            17434.0    0.080704    0.475491    0.0    0.0    0.0
# decile_score             17434.0    5.039119    2.934683   -1.0    2.0    5.0
# juv_misd_count           17434.0    0.103419    0.530087    0.0    0.0    0.0
# juv_other_count          17434.0    0.129746    0.536004    0.0    0.0    0.0
# priors_count             17434.0    4.109499    5.357596    0.0    1.0    2.0
# days_b_screening_arrest  17004.0    4.294460   81.183415 -597.0   -1.0   -1.0
# c_days_from_compas       17434.0   57.642193  317.892979    0.0    1.0    1.0
# is_violent_recid         17434.0    0.076460    0.265740    0.0    0.0    0.0
# decile_score.1           17434.0    5.039119    2.934683   -1.0    2.0    5.0
# v_decile_score           17434.0    4.052254    2.616827   -1.0    2.0    4.0
# priors_count.1           17434.0    4.109499    5.357596    0.0    1.0    2.0
# start                    17434.0  190.519617  284.907752    0.0    0.0   11.0
# end                      17434.0  619.394172  336.475010    0.0  353.0  627.0
# event                    17434.0    0.046748    0.211104    0.0    0.0    0.0
#
#                             75%     max
# age                       41.00    96.0
# juv_fel_count              0.00    20.0
# decile_score               8.00    10.0
# juv_misd_count             0.00    13.0
# juv_other_count            0.00    17.0
# priors_count               6.00    43.0
# days_b_screening_arrest    0.00  1057.0
# c_days_from_compas         2.00  9485.0
# is_violent_recid           0.00     1.0
# decile_score.1             8.00    10.0
# v_decile_score             6.00    10.0
# priors_count.1             6.00    43.0
# start                    320.75  1197.0
# end                      892.00  1187.0
# event                      0.00     1.0
